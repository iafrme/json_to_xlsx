# %%
import pandas as pd

excel = pd.read_json("jsons/PA_DI_2018_01_001.json")
excel.drop('date', inplace=True, axis=1, errors='ignore')

excel.to_excel('PA_NO_2018_09_001.xlsx', index=False)
excel
# Out:
#    abandoned                answerable  area  client country  \
# 0          N         Department Patent     2   50347      MX
# 1          N       Christopher Franich     2   55422      MX
# 2          N  Ms. Lisa M. Hemmendinger     2   52121      MX
# 3          N          Jay S. Pattumudi     2   50137      MX
# 4          N  Ms. Lisa M. Hemmendinger     2   52121      MX
# 5          N                   Tony Ly     2    4691      MX
# 6          N           Jochen Bongards     2   54642      MX
# 7          N          Lesley L. Andrew     2    3402      MX
# 8          N          Lesley L. Andrew     2    3402      MX
# 9          N                   Tony Ly     2    4691      MX
# 10         N                   Tony Ly     2    4691      MX
# 11         N          Lesley L. Andrew     2    3402      MX
# 12         N          Lesley L. Andrew     2    3402      MX
# 13         N    Natalie DeVleeschauwer     2      63      MX
# 14         N         PATENT DEPARTMENT     2   50347      MX
# 15         N         PATENT DEPARTMENT     2   50347      MX
# 16         N         PATENT DEPARTMENT     2   50347      MX
# 17         N            Juan P. FERRER     2   52268      MX
# 18         N             Dr V. Metzler     2   51269      MX
# 19         N         Patent Department     2   50347      MX
#
#     date_of_circulation  destination_agent  figure  file_number grant_number  \
# 0              20180222                  0     101        12186       279836
# 1              20180222                  0     101         5966       333245
# 2              20180222                  0     101         9782       320524
# 3              20180222                  0     101         1462       331090
# 4              20180222                  0     101         6322
# 5              20180222                  0     101        15175
# 6              20180222                  0     101        17368
# 7              20180222                  0     101        18035
# 8              20180222                  0     101         2747
# 9              20180222                  0     101         7283
# 10             20180222                  0     101         8354
# 11             20180222                  0     101         4628
# 12             20180222                  0     101         4630
# 13             20180222                  0     101         6930
# 14             20180222                  0     101         7549       218454
# 15             20180222                  0     101         7550       219751
# 16             20180222                  0     101         8324       220719
# 17             20180222                  0     101         6237       232120
# 18             20180222                  0     101         7819       295445
# 19             20180222                  0     101         7575       256126
#
#    granted   panref  priority    request_number  \
# 0   279836  P150722         0  MX/a/2008/012186
# 1   333245  P121637         2  MX/a/2012/005966
# 2   320524  P122547         2  MX/a/2012/009782
# 3   331090  P133936         3  MX/a/2014/001462
# 4           P141622         2  MX/a/2014/006322
# 5           P154070         3  MX/a/2015/015175
# 6           P154591         2  MX/a/2015/017368
# 7           P154847         2  MX/a/2015/018035
# 8           P162480         2  MX/a/2016/002747
# 9           P163843         2  MX/a/2016/007283
# 10          P163882         4  MX/a/2016/008354
# 11          P171142         2  MX/a/2017/004628
# 12          P171149         2  MX/a/2017/004630
# 13          P172036         2  MX/a/2017/006930
# 14  218454  P143527         0  PA/a/2000/007549
# 15  219751  P143526         0  PA/a/2000/007550
# 16  220719  P140189         0  PA/a/2000/008324
# 17  232120  P172744         0  PA/a/2002/006237
# 18  295445  P041859         1  PA/a/2004/007819
# 19  256126  P130040         0  PA/a/2005/007575
#
#                                                 title  type
# 0   PORTADOR BIOADHESIVO MUCOSAL DE LIBERACION RET...   102
# 1   DISPOSITIVO DE COMPRESIαN GRADUADA PARA EL TRA...   102
# 2   PROCESOS PARA LA SINTESIS DE DIARILTIOHIDANTOI...   102
# 3   CIRCUITO INTEGRADO AL VAC╓O DE ALTA CORRIENTE ...   101
# 4   PROCESOS PARA LA SINTESIS DE DIARILTIOHIDANTOI...   101
# 5   FORMULACIONES DE SAL DE NICOTINA PARA DISPOSIT...   102
# 6   DISPOSITIVO DE TRANSPORTE PARA DISPOSITIVO DE ...   102
# 7   METODOS PARA PREDECIR RESPUESTAS A SUSTANCIAS ...   103
# 8   MÉTODOS PARA ESTUDIOS DE ASOCIACIαN GENÉTICA, ...   103
# 9   FORMULACIαN L╓QUIDA DE NICOTINA PARA DISPOSIIV...   102
# 10    DISPOSITIVO, SISTEMAS Y MÉTODOS DE VAPORIZACIαN   102
# 11  PLATAFORMA Y MÉTODOS PARA ANALIZAR EFECTOS DE ...   102
# 12  MÉTODOS PARA LLEVAR A CABO ESTUDIOS DE EST╓MUL...   102
# 13                         PROCESO DE OXI-CALCINACIαN   102
# 14  SISTEMA Y METODO DE CONFERENCIA EN TELECOMUNIC...   102
# 15  APARATO Y METODO DE TELECOMUNICACIONES PARA EN...   102
# 16         UNIDAD TELEFONICA DE POSICIONES MULTIPLES.   102
# 17  USO DE DEXTROMETORFANO E INHIBIDOR DE OXIDASA ...   103
# 18           COMBINADO DE CAPAS APLICADAS EN TARJETAS   101
# 19  :SISTEMA Y METODO PARA LA GENERACION DE CODIGO...   102
